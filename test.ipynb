# %%
from pandas import DataFrame

# %%
a = DataFrame.from_csv('data/Brain_map.csv')
a
# Out:
#              100, 57, 0                  100, 57, 1          100, 57, 10  \
# 0        baba: 0.007193          gespenst: 0.010964       papa: 0.011549
# 1  kinderbuch: 0.006982              taub: 0.009241     gipfel: 0.010206
# 2    munition: 0.006937  krankenschwester: 0.009034         in: 0.009998
# 3   politiker: 0.006244              baba: 0.008981       haus: 0.009241
# 4     gipfeln: 0.005988         politiker: 0.008655       baba: 0.009097
# 5       krieg: 0.005889             taube: 0.008490        tag: 0.008950
# 6    gespenst: 0.005815           friseur: 0.008125  weststadt: 0.008775
# 7       stadt: 0.005517            putzen: 0.008060  forsthaus: 0.008738
# 8     fliegen: 0.005248              halb: 0.007866      anzug: 0.008489
# 9       klein: 0.005126              held: 0.007826    stiefel: 0.008457
#
#             100, 57, 11           100, 57, 12           100, 57, 13  \
# 0      backen: 0.009356        nike: 0.009932        nike: 0.010180
# ...
